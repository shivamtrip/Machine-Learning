# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
x1 = pd.read_csv('../input/house-prices-advanced-regression-techniques/train.csv')
x2 = x1.set_index('Id')

for i in range(len(x2.columns)):
    if x2.isnull().sum()[i] > 200:
        print(x2.isnull().sum().index[i] + " - " + str(x2.isnull().sum()[i]))

x4 = x2.drop('MiscFeature', axis = 1)

x4 = x4.drop('Fence', axis = 1)

x4 = x4.drop('Alley', axis = 1)

x4 = x4.drop('PoolQC', axis = 1)

# %%
x4 = x2.drop('MiscFeature', axis = 1)

x4 = x4.drop('Fence', axis = 1)

x4 = x4.drop('Alley', axis = 1)

x4 = x4.drop('PoolQC', axis = 1)

# %%
for i in range(len(x4.columns)):
    if x4.isnull().sum()[i] > 200:
        print(x4.isnull().sum().index[i] + " - " + str(x4.isnull().sum()[i]))

# %%
x4.FireplaceQu.fillna("TA", inplace = True)

# %%
for i in range(len(x4.columns)):
    if x4.isnull().sum()[i] > 200:
        print(x4.isnull().sum().index[i] + " - " + str(x4.isnull().sum()[i]))

# %%
x4.LotFrontage.fillna(x4.LotFrontage.mean(), inplace = True)

# %%
for i in range(len(x4.columns)):
    if x4.isnull().sum()[i] > 0:
        print(x4.isnull().sum().index[i] + " - " + str(x4.isnull().sum()[i]))

# %%
x4.MasVnrArea.fillna(x4.MasVnrArea.mean(), inplace = True)

# %%
for i in range(len(x4.columns)):
    if x4.isnull().sum()[i] > 0:
        print(x4.isnull().sum().index[i] + " - " + str(x4.isnull().sum()[i]))

# %%
for i in range(len(x4.columns)):
    if x4.isnull().sum()[i] > 0:
        print(x4.isnull().sum().index[i] + " - " + str(x4.isnull().sum()[i]))

# %%
s = []
for i in range(len(x4.columns)):
    if x4.isnull().sum()[i] > 0:
        s.append(x4.isnull().sum().index[i])

# %%
for i in s:
    x4[i].fillna("NA", inplace = True)

# %%
for i in range(len(x4.columns)):
    if x4.isnull().sum()[i] > 0:
        print(x4.isnull().sum().index[i] + " - " + str(x4.isnull().sum()[i]))

# %%
from sklearn.preprocessing import LabelEncoder

# %%
x5 = x4.copy()

label_encoder = LabelEncoder()

for col in object_cols:
    x5[col] = label_encoder.fit_transform(x4[col])

# %%
x6 = x5.drop('SalePrice', axis = 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x6, y1, test_size = 0.4, random_state = 4)

# %%
from xgboost import XGBRegressor

my_model = XGBRegressor(n_estimators=500)
my_model.fit(X_train, y_train, 
             early_stopping_rounds=5, 
             eval_set=[(X_test, y_test)],
             verbose=False)

# %%
from sklearn.metrics import mean_absolute_error

predictions = my_model.predict(X_test)
print("Mean Absolute Error: " + str(mean_absolute_error(predictions, y_test)))

# %%
X1 = pd.read_csv('../input/house-prices-advanced-regression-techniques/test.csv')

# %%
X2 = X1.set_index('Id')

# %%
for i in range(len(X2.columns)):
    if X2.isnull().sum()[i] > 200:
        print(X2.isnull().sum().index[i] + " - " + str(X2.isnull().sum()[i]))

# %%
X4 = X2.drop('MiscFeature', axis = 1)

# %%
X4 = X4.drop('Fence', axis = 1)

X4 = X4.drop('Alley', axis = 1)

X4 = X4.drop('PoolQC', axis = 1)

# %%
X4

# %%
X4.FireplaceQu.fillna("TA", inplace = True)

# %%
X4.LotFrontage.fillna(x4.LotFrontage.mean(), inplace = True)

# %%
s = []
for i in range(len(X4.columns)):
    if X4.isnull().sum()[i] > 0:
        s.append(X4.isnull().sum().index[i])

# %%
y = (X4.dtypes == 'object')
object_cols = list(y[y].index)

# %%
z = []
for i in s:
    if i not in object_cols:
        z.append(i)

# %%
z

# %%
for i in z:
    X4[i].fillna( x4[i].mean(), inplace = True)

# %%
q = []
for i in range(len(X4.columns)):
    if X4.isnull().sum()[i] > 0:
        q.append(X4.isnull().sum().index[i])

# %%
z = []
for i in q:
    if i not in object_cols:
        z.append(i)

# %%
s = []
for i in range(len(X4.columns)):
    if X4.isnull().sum()[i] > 0:
        s.append(X4.isnull().sum().index[i])

# %%
for i in s:
    print(x4[i])

# %%
s.clear()
for i in range(len(X4.columns)):
    if X4.isnull().sum()[i] > 0:
        s.append(X4.isnull().sum().index[i])

# %%
for i in s:
    X4[i].fillna("NA", inplace = True)

# %%
for i in range(len(X4.columns)):
    if X4.isnull().sum()[i] > 0:
        print(X4.isnull().sum().index[i])

# %%
X5 = X4.copy()

label_encoder = LabelEncoder()

for col in object_cols:
    X5[col] = label_encoder.fit_transform(X4[col])

# %%
X5

# %%
final_ans = my_model.predict(X5)

# %%
output = pd.DataFrame({'Id': X5.index,
                       'SalePrice': final_ans})
output.to_csv('submission2.csv', index=False)
